# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('price forecast.csv')
data.head()
# Out:
#   Close price Exchange Date Timestamp (coc-mpyn-prfr)  \
# 0         561      4-Jan-00                  1/4/2000
# 1         560      5-Jan-00                  1/5/2000
# 2         556      6-Jan-00                  1/6/2000
# 3         564      7-Jan-00                  1/7/2000
# 4         565     10-Jan-00                 1/10/2000
#
#    Last Quote Close (coc-mpyn-prfr) Timestamp (coc-mpys-prfr)  \
# 0                          0.000000                  1/1/2000
# 1                          0.000000                  1/2/2000
# 2                         -0.004343                  1/3/2000
# 3                          0.002181                  1/4/2000
# 4                         -0.014851                  1/5/2000
#
#    Last Quote Close(coc-mpys-prfr) Timestamp(coc-mpyns-prfr)  \
# 0                              0.0                  1/1/2000
# 1                              0.0                  1/2/2000
# 2                              0.0                  1/3/2000
# ...

# %%
data.tail()
# Out:
#      Close price Exchange Date Timestamp (coc-mpyn-prfr)  \
# 7211         NaN           NaN                       NaN
# 7212         NaN           NaN                       NaN
# 7213         NaN           NaN                       NaN
# 7214         NaN           NaN                       NaN
# 7215         NaN           NaN                       NaN
#
#       Last Quote Close (coc-mpyn-prfr) Timestamp (coc-mpys-prfr)  \
# 7211                               NaN                       NaN
# 7212                               NaN                       NaN
# 7213                               NaN                       NaN
# 7214                               NaN                       NaN
# 7215                               NaN                       NaN
#
#       Last Quote Close(coc-mpys-prfr) Timestamp(coc-mpyns-prfr)  \
# 7211                              NaN                       NaN
# 7212                              NaN                       NaN
# ...

# %%
pd.datetime('data[Timestamp(coc-mpyn-prfr)]', format = '%d-%m-%y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-52d80889a9b9> in <module>
# ----> 1 pd.datetime('data[Timestamp(coc-mpyn-prfr)]', format = '%d-%m-%y')
#
# TypeError: an integer is required (got type str)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7216 entries, 0 to 7215
# Data columns (total 14 columns):
# Close price                         4957 non-null object
# Exchange Date                       4957 non-null object
# Timestamp (coc-mpyn-prfr)           7029 non-null object
# Last Quote Close (coc-mpyn-prfr)    7029 non-null float64
# Timestamp (coc-mpys-prfr)           6937 non-null object
# Last Quote Close(coc-mpys-prfr)     6937 non-null float64
# Timestamp(coc-mpyns-prfr)           7047 non-null object
# Last Quote Close(coc-mpyns-prfr)    7047 non-null float64
# Timestamp (coc-mpyn-wdam)           6939 non-null object
# Last Quote Close(coc-mpyn-wdam)     6939 non-null float64
# Timestamp(coc-mpys-wdam)            7190 non-null object
# Last Quote Close(coc-mpys-wdam)     7190 non-null float64
# Timestamp(coc-mpyns-wdam)           7216 non-null object
# Last Quote Close(coc-mpyns-wdam)    7216 non-null float64
# dtypes: float64(6), object(8)
# ...

# %%
#import matplotlib.pyplot as plt
#data.hist()

# %%
#pd.options.display.mpl_style = 'default'
#data.boxplot()
